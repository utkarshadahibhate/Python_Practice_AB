# %% [markdown]
# ### Introduction to files

# %% [markdown]
# - Introduction
# - Modes of files
# - Operations on files
# - Random Access files
# - Pickle and Unpickle
# - Zip and UnZip

# %%
#######
